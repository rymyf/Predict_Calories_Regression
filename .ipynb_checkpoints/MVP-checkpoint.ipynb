# %% [markdown]
# # __Predicting Burned Calories on Workout__

# %% [markdown]
# <p align="center">
#   <img src="https://github.com/rymyf/Predict_Calories_Regression/blob/main/pics/rock-art-craft-wellness.jpg?raw=true" alt="Material Bread logo">
# </p>

# %% [markdown]
# ## __Contents:__
# > 1. Overview
# > 2. Installation
# > 3. Read the dataset
# > 4. Explore Information
# > 5. Cleaning the dataset
# >> 1. Handling whitespaces
# >> 2. Handling the Missing Values
# >> 3. Handling the Outliers
# >> 4. Export the cleaned dataset
# > 6. Explore Data Analysis
# >> 1. Questions & Answers

# %% [markdown]
# ---

# %% [markdown]
# ## __Overview:__
#
# In this project we take the dataset from kaggle [here](https://www.kaggle.com/emdemor/predicting-burned-calories-on-workout/data)

# %% [markdown]
# ---

# %% [markdown]
# ## __Installation:__

# %%
# !pip install plotly_express

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px

# %load_ext autotime
# %config InlineBackend.figure_format = 'svg'
# Out:
# time: 9.36 ms (started: 2021-11-26 22:07:57 +03:00)

# %% [markdown]
# ---

# %% [markdown]
# ## __Read the Dataset:__

# %%
# Import Calories Dataset
df_cal = pd.read_csv('data/calories.csv')

# Import Exercises Dataset
df_ex  = pd.read_csv('data/exercise.csv')

# Merging Datasets
df = pd.merge(df_ex, df_cal, on = 'User_ID')
df.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female   27   154.0    58.0      10.0        81.0       39.8
#
#    Calories
# 0     231.0
# 1      66.0
# 2      26.0
# 3      71.0
# 4      35.0
# time: 110 ms (started: 2021-11-26 22:08:07 +03:00)

# %% [markdown]
# ---

# %% [markdown]
# ## __Explore Information:__

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15000 entries, 0 to 14999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_ID     15000 non-null  int64
#  1   Gender      15000 non-null  object
#  2   Age         15000 non-null  int64
#  3   Height      15000 non-null  float64
#  4   Weight      15000 non-null  float64
#  5   Duration    15000 non-null  float64
#  6   Heart_Rate  15000 non-null  float64
#  7   Body_Temp   15000 non-null  float64
#  8   Calories    15000 non-null  float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 1.1+ MB
# time: 37 ms (started: 2021-11-25 01:59:41 +03:00)

# %%
df.describe()
# Out:
#             User_ID           Age        Height        Weight      Duration  \
# count  1.500000e+04  15000.000000  15000.000000  15000.000000  15000.000000
# mean   1.497736e+07     42.789800    174.465133     74.966867     15.530600
# std    2.872851e+06     16.980264     14.258114     15.035657      8.319203
# min    1.000116e+07     20.000000    123.000000     36.000000      1.000000
# 25%    1.247419e+07     28.000000    164.000000     63.000000      8.000000
# 50%    1.499728e+07     39.000000    175.000000     74.000000     16.000000
# 75%    1.744928e+07     56.000000    185.000000     87.000000     23.000000
# max    1.999965e+07     79.000000    222.000000    132.000000     30.000000
#
#          Heart_Rate     Body_Temp      Calories
# count  15000.000000  15000.000000  15000.000000
# mean      95.518533     40.025453     89.539533
# std        9.583328      0.779230     62.456978
# min       67.000000     37.100000      1.000000
# 25%       88.000000     39.600000     35.000000
# 50%       96.000000     40.200000     79.000000
# 75%      103.000000     40.600000    138.000000
# max      128.000000     41.500000    314.000000
# time: 61.5 ms (started: 2021-11-25 02:00:06 +03:00)

# %%
df.size
# Out:
# 135000
# time: 4.77 ms (started: 2021-11-25 02:00:32 +03:00)

# %%
df.shape
# Out:
# (15000, 9)
# time: 6.39 ms (started: 2021-11-25 02:02:05 +03:00)

# %%
df.columns
# Out:
# Index(['User_ID', 'Gender', 'Age', 'Height', 'Weight', 'Duration',
#        'Heart_Rate', 'Body_Temp', 'Calories'],
#       dtype='object')
# time: 16.3 ms (started: 2021-11-25 02:02:16 +03:00)

# %%
df.dtypes
# Out:
# User_ID         int64
# Gender         object
# Age             int64
# Height        float64
# Weight        float64
# Duration      float64
# Heart_Rate    float64
# Body_Temp     float64
# Calories      float64
# dtype: object
# time: 7.03 ms (started: 2021-11-25 02:03:00 +03:00)

# %%
df.Gender.value_counts()
# Out:
# female    7553
# male      7447
# Name: Gender, dtype: int64
# time: 15.8 ms (started: 2021-11-25 02:05:09 +03:00)

# %%
df.Age.nunique()
# Out:
# 60
# time: 3.66 ms (started: 2021-11-25 02:06:24 +03:00)

# %%
df.Age.unique()
# Out:
# array([68, 20, 69, 34, 27, 36, 33, 41, 60, 26, 21, 66, 32, 53, 39, 46, 50,
#        67, 31, 48, 29, 42, 62, 38, 25, 24, 22, 74, 70, 44, 61, 63, 54, 47,
#        35, 28, 77, 64, 45, 57, 49, 40, 55, 23, 43, 52, 79, 51, 59, 30, 37,
#        56, 58, 78, 73, 76, 72, 65, 71, 75])
# time: 14.8 ms (started: 2021-11-25 02:06:36 +03:00)

# %%
df.Age.value_counts()
# Out:
# 20    512
# 21    497
# 22    489
# 26    452
# 25    435
# 24    426
# 23    411
# 27    396
# 28    390
# 29    379
# 32    370
# 31    339
# 35    327
# 30    325
# 33    320
# 38    311
# 34    285
# 37    283
# 36    279
# 39    276
# 40    260
# 44    259
# 42    257
# 41    252
# 43    250
# 46    233
# 45    233
# 52    225
# 47    223
# 50    220
# 48    219
# 54    217
# 49    208
# 55    204
# 53    201
# 59    198
# 51    197
# 56    190
# 63    182
# 58    182
# 61    181
# 62    180
# 57    177
# 64    176
# 60    172
# 65    169
# 73    167
# 71    163
# 67    162
# 70    154
# 68    150
# 66    147
# 79    147
# 69    145
# 74    142
# 76    139
# 72    137
# 78    133
# 77    130
# 75    117
# Name: Age, dtype: int64
# time: 18.7 ms (started: 2021-11-25 02:06:00 +03:00)

# %%
df.sample(60)
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 5083   18154398    male   28   181.0    81.0      30.0       108.0       41.1
# 11499  12549363  female   45   154.0    52.0      26.0       107.0       40.6
# 4474   11910418    male   20   179.0    78.0      15.0        88.0       40.3
# 6150   16801836    male   29   175.0    73.0      27.0        98.0       40.9
# 7978   13708815  female   43   157.0    60.0      28.0       110.0       40.9
# 6066   19117012  female   66   171.0    62.0       3.0        80.0       38.6
# 5624   19308183  female   38   156.0    52.0      25.0       100.0       40.6
# 7206   14605804    male   51   186.0    88.0       3.0        81.0       38.6
# 5174   18252820  female   24   158.0    56.0       6.0        79.0       39.6
# 9172   17628194  female   67   169.0    67.0      17.0        92.0       40.2
# 5638   15708106  female   77   177.0    79.0       4.0        83.0       39.0
# 1383   10580116  female   47   162.0    64.0      18.0        94.0       40.7
# 4729   10020368  female   22   151.0    50.0       7.0        98.0       39.5
# 12232  13845948  female   32   157.0    53.0      10.0        92.0       40.0
# 12324  12859082  female   76   162.0    66.0      15.0        87.0       39.9
# 8851   18662357    male   28   181.0    82.0       2.0        88.0       37.8
# 13628  18229937  female   49   170.0    67.0      21.0        93.0       40.9
# 12324      73.0
# 8851        6.0
# 13628     105.0
# 10302      58.0
# 7958      115.0
# 12682     172.0
# 8064       87.0
# 2676      204.0
# 12326      98.0
# 1074      121.0
# 12205      86.0
# 13090      79.0
# 14519     202.0
# 11297      20.0
# 14074      87.0
# 339       121.0
# 7508       30.0
# 5022       99.0
# 8579       24.0
# 3481       62.0
# 7209       14.0
# 10918     230.0
# 4361       59.0
# 1493       62.0
# 13137      52.0
# 6169      167.0
# 14237     136.0
# 9436      223.0
# 9414        6.0
# 161       239.0
# 13084      21.0
# 10646      88.0
# 6022       61.0
# 8293       37.0
# 12738       5.0
# 502       117.0
# 3440      155.0
# 10004      49.0
# 5115       39.0
# 5146        2.0
# 3793       12.0
# 5345       69.0
# 1583       41.0
# 14245      57.0
# 12982     155.0
# 5411       20.0
# time: 87.6 ms (started: 2021-11-25 02:04:32 +03:00)

# %% [markdown]
# ---

# %% [markdown]
# ## __Cleaning the Dataset:__

# %% [markdown]
# ### Handling whitespaces:

# %%
# strip whitespaces in columns
df.columns.str.strip()
# Out:
# Index(['User_ID', 'Gender', 'Age', 'Height', 'Weight', 'Duration',
#        'Heart_Rate', 'Body_Temp', 'Calories'],
#       dtype='object')
# time: 6.08 ms (started: 2021-11-25 02:08:18 +03:00)

# %%
# strip whitespaces in values of multiple columns
df['Gender'] = df['Gender'].apply(lambda x: x.strip())
# Out:
# time: 4.3 ms (started: 2021-11-25 02:10:40 +03:00)

# %% [markdown]
# ### Handling the Missing Values:

# %%
# Check for null values
df.isna().sum()
# Out:
# User_ID       0
# Gender        0
# Age           0
# Height        0
# Weight        0
# Duration      0
# Heart_Rate    0
# Body_Temp     0
# Calories      0
# dtype: int64
# time: 19.9 ms (started: 2021-11-25 02:15:47 +03:00)

# %% [markdown]
# ### Handling the Outliers:

# %%
# Find Outliers

# %% [markdown]
# ### Export the cleaned dataset:

# %%
# df.to_csv("cleaned_exer_cal_dataset.csv")

# %% [markdown]
# ## __Explore Data Analysis:__

# %% [markdown]
# ### Questions & Answers:

# %% [markdown]
# #### 1. How can age affect performance time during a workout?

# %%
# Code

# %%
# Visual

# %% [markdown]
# #### 2. What are the factors that affect how high or low heart rate during a workout?

# %%
# Code

# %%
# Visual

# %% [markdown]
# #### 3. What is the rate of burning calories compared to the time of workout?

# %%
# Code

# %%
# Visual

# %% [markdown]
# #### 4. What is the difference between male and female in the duration of workout and burned calories?

# %%
# Code

# %%
# Visual

# %% [markdown]
# #### 5. What is the relationship between weight and burned calories?

# %%
# Code

# %%
# Visual

# %% [markdown]
# #### 6. What are the oldest ages that achieve high calorie burn?

# %%
# Code

# %%
# Visual

# %% [markdown]
# #### 7. What is the difference between male and female in height and weight?

# %%
# Code
grouped_gender = df.groupby('Gender',as_index=False)[['Height','Weight']].mean()
grouped_gender
# Out:
#    Gender      Height     Weight
# 0  female  164.405931  63.274460
# 1    male  184.667517  86.825702
# time: 42.9 ms (started: 2021-11-26 15:35:51 +03:00)

# %%
# Visual
reshape = {'Gender': ['female', 'female', 'male', 'male'], 'measure': ['Height',  'Weight', 'Height',  'Weight'], 'value':[grouped_gender.values[0][1], grouped_gender.values[0][2], grouped_gender.values[1][1], grouped_gender.values[1][2]]} 
reshape_grouped_gender = pd.DataFrame(data=reshape)
reshape_grouped_gender
sns.set_style("whitegrid")
sns.factorplot(x='Gender', y='value', hue='measure', data=reshape_grouped_gender, kind='bar');
# Out:
# /Users/RAHAF/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# time: 959 ms (started: 2021-11-26 15:43:53 +03:00)
